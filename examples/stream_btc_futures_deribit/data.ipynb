# %%
import polars as pl
import numpy as np

df = pl.read_parquet('./data/orderbooks/parquet/btc_futures_20251116_194259.parquet')
df
# Out:
# shape: (222, 9)
# ┌─────────────┬─────────────┬──────────┬──────────┬───┬───────────┬────────┬───────────┬───────────┐
# │ timestamp   ┆ symbol      ┆ exchange ┆ best_bid ┆ … ┆ mid_price ┆ spread ┆ bid_depth ┆ ask_depth │
# │ ---         ┆ ---         ┆ ---      ┆ ---      ┆   ┆ ---       ┆ ---    ┆ ---       ┆ ---       │
# │ datetime[ns ┆ str         ┆ str      ┆ f64      ┆   ┆ f64       ┆ f64    ┆ i64       ┆ i64       │
# │ ]           ┆             ┆          ┆          ┆   ┆           ┆        ┆           ┆           │
# ╞═════════════╪═════════════╪══════════╪══════════╪═══╪═══════════╪════════╪═══════════╪═══════════╡
# │ 2025-11-16  ┆ BTC-FS-21NO ┆ deribit  ┆ 7.5      ┆ … ┆ 7.75      ┆ 0.5    ┆ 10        ┆ 13        │
# │ 19:42:58.94 ┆ V25_PERP    ┆          ┆          ┆   ┆           ┆        ┆           ┆           │
# │ 4           ┆             ┆          ┆          ┆   ┆           ┆        ┆           ┆           │
# ...

# %%
df['symbol'].unique().to_pandas()
# Out:
# 0          BTC-FS-26DEC25_PERP
# 1           BTC/USD:BTC-260626
# 2           BTC/USD:BTC-251128
# 3       BTC-FS-27MAR26_28NOV25
# 4          BTC-FS-27MAR26_PERP
# 5       BTC-FS-25SEP26_27MAR26
# 6       BTC-FS-26JUN26_26DEC25
# 7       BTC-FS-25SEP26_28NOV25
# 8       BTC-FS-27MAR26_21NOV25
# 9           BTC/USD:BTC-260327
# 10      BTC-FS-25SEP26_26DEC25
# 11      BTC-FS-26JUN26_27MAR26
# 12         BTC-FS-26JUN26_PERP
# 13      BTC-FS-26DEC25_28NOV25
# 14      BTC-FS-25SEP26_26JUN26
# 15         BTC-FS-21NOV25_PERP
# 16    BTCDVOL/USDC:USDC-251126
# 17      BTC-FS-26DEC25_21NOV25
# 18      BTC-FS-25SEP26_21NOV25
# 19         BTC-FS-25SEP26_PERP
# 20      BTC-FS-27MAR26_26DEC25
# 21      BTC-FS-26JUN26_21NOV25
# 22      BTC-FS-28NOV25_21NOV25
# 23          BTC/USD:BTC-260925
# 24          BTC/USD:BTC-251121
# 25    BTC_USDC-FS-28NOV25_PERP
# 26      BTC-FS-26JUN26_28NOV25
# 27          BTC/USD:BTC-251226
# 28        BTC/USDC:USDC-251128
# 29         BTC-FS-28NOV25_PERP
# ...
