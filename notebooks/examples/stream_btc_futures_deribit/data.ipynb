# %%
import polars as pl
import numpy as np

df = pl.read_parquet('./data/output.parquet')
df
# Out:
# shape: (301, 43)
# ┌─────────────────────┬──────────────┬──────────┬────────┬───┬───────┬──────────┬───────┬──────────┐
# │ symbol              ┆ timestamp    ┆ exchange ┆ bid1   ┆ … ┆ bid10 ┆ bidamt10 ┆ ask10 ┆ askamt10 │
# │ ---                 ┆ ---          ┆ ---      ┆ ---    ┆   ┆ ---   ┆ ---      ┆ ---   ┆ ---      │
# │ str                 ┆ datetime[ns] ┆ str      ┆ f64    ┆   ┆ f64   ┆ f64      ┆ f64   ┆ f64      │
# ╞═════════════════════╪══════════════╪══════════╪════════╪═══╪═══════╪══════════╪═══════╪══════════╡
# │ BTC-FS-25SEP26_26DE ┆ 2025-11-21   ┆ deribit  ┆ 3318.5 ┆ … ┆ null  ┆ null     ┆ null  ┆ null     │
# │ C25                 ┆ 21:05:16.020 ┆          ┆        ┆   ┆       ┆          ┆       ┆          │
# │ BTC-FS-25SEP26_26JU ┆ 2025-11-21   ┆ deribit  ┆ 1182.5 ┆ … ┆ null  ┆ null     ┆ null  ┆ null     │
# │ N26                 ┆ 21:05:16.368 ┆          ┆        ┆   ┆       ┆          ┆       ┆          │
# ...
